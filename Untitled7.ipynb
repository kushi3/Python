# %% [markdown]
# <a href="https://colab.research.google.com/github/kushi3/Python/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AntonMu/TrainYourOwnYOLO.git
# Out:
# Cloning into 'TrainYourOwnYOLO'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 2266 (delta 1), reused 2 (delta 0), pack-reused 2259
# Receiving objects: 100% (2266/2266), 142.02 MiB | 25.34 MiB/s, done.
# Resolving deltas: 100% (741/741), done.

# %%
# %cd TrainYourOwnYOLO/Data/Source_Images/
# Out:
# /content/TrainYourOwnYOLO/Data/Source_Images

# %%
# !rm -rf Training_Images

# %%
# !rm -rf Test_Images

# %%
# !rm -rf Test_Image_Detection_Results/

# %%
# %cd ..
# Out:
# /content

# %%
# %cd TrainYourOwnYOLO
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 1_Image_Annotation/
# Out:
# /content/TrainYourOwnYOLO/1_Image_Annotation

# %%
# !python Convert_to_YOLO_format.py

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 2_Training/
# Out:
# /content/TrainYourOwnYOLO/2_Training

# %%
# !python Download_and_Convert_YOLO_weights.py
# Out:
# 100% (2480070 of 2480070) |###############| Elapsed Time: 0:11:21 ETA:  00:00:00Using TensorFlow backend.
# 2020-04-30 15:17:24.188009: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# 2020-04-30 15:17:25.728282: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-30 15:17:25.793435: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-30 15:17:25.794311: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# ...

# %%
import keras
print(keras.__version__)
# Out:
# Using TensorFlow backend.
# 2.3.1

# %%
# !python Train_YOLO.py
# Out:
# Using TensorFlow backend.
# 2020-04-30 15:31:01.951650: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-04-30 15:31:03.414080: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-30 15:31:03.427503: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-30 15:31:03.428087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-04-30 15:31:03.428127: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !pip install keras==2.3.1

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 3_Inference/
# Out:
# /content/TrainYourOwnYOLO/3_Inference

# %%
# !python Detector.py
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !pip install tensorflow==1.14.0
# !pip install keras==2.2.0
# Out:
# ...
#      |████████████████████████████████| 109.2MB 38kB/s
# ...
#      |████████████████████████████████| 491kB 59.6MB/s
# ...
#      |████████████████████████████████| 3.2MB 49.7MB/s
# ...
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: tensorboard 1.12.2
#     Uninstalling tensorboard-1.12.2:
#       Successfully uninstalled tensorboard-1.12.2
#   Found existing installation: tensorflow 1.12.0
#     Uninstalling tensorflow-1.12.0:
#       Successfully uninstalled tensorflow-1.12.0
# ...
#      |████████████████████████████████| 307kB 8.1MB/s
# ...
#      |████████████████████████████████| 51kB 8.3MB/s
# ...
# ERROR: tensorflow 1.14.0 has requirement keras-applications>=1.0.6, but you'll have keras-applications 1.0.2 which is incompatible.
# ...

# %%
# !pip install tensorflow==1.12
# Out:
# ...
#      |████████████████████████████████| 83.1MB 52kB/s
# ...
#      |████████████████████████████████| 3.1MB 52.1MB/s
# ...
#   Found existing installation: tensorboard 2.2.1
#     Uninstalling tensorboard-2.2.1:
#       Successfully uninstalled tensorboard-2.2.1
#   Found existing installation: tensorflow 2.2.0rc3
#     Uninstalling tensorflow-2.2.0rc3:
#       Successfully uninstalled tensorflow-2.2.0rc3
# ...

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd Data/Source_Images/
# Out:
# /content/TrainYourOwnYOLO/Data/Source_Images

# %%
# !rm -rf Training_Images/

# %%
# !rm -rf Test_Images

# %%
# !rm -rf Test_Image_Detection_Results

# %%
# %cd Training_Images/
# Out:
# /content/TrainYourOwnYOLO/Data/Source_Images/Training_Images

# %%
# !rm -rf vott-export-csv

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 1_Image_Annotation/
# Out:
# /content/TrainYourOwnYOLO/1_Image_Annotation

# %%
# !python Convert_to_YOLO_format.py

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 2_Training/
# Out:
# /content/TrainYourOwnYOLO/2_Training

# %%
# !python Download_and_Convert_YOLO_weights.py
# Out:
#  99% (2479715 of 2480070) |############## | Elapsed Time: 0:07:47 ETA:   0:00:00Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %%
# !python Train_YOLO.py
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# %cd ..

# %%
# %cd 3_Inference

# %%
# !python Train_YOLO.py

# %% [markdown]
# https://stackoverflow.com/questions/58963553/attributeerror-module-tensorflow-python-keras-backend-has-no-attribute-get-g
#
#
# https://github.com/keras-team/keras/issues/12379
#
# https://github.com/OlafenwaMoses/ImageAI/issues/367
#
# https://blog.insightdatascience.com/how-to-train-your-own-yolov3-detector-from-scratch-224d10e55de2
#
# https://github.com/AntonMu/TrainYourOwnYOLO/tree/master/1_Image_Annotation
#
# https://blog.csdn.net/CAU_Ayao/article/details/89312354
#
# https://github.com/AntonMu/TrainYourOwnYOLO/issues/48
#
# https://github.com/AntonMu/TrainYourOwnYOLO

# %% [markdown]
# solving attribute errors,module not found errors,import errors
#
# add
#
# import tensorflow.python.ops import control_flow_ops in Tensorflow backend.py
#
# in __init.py__ we add
# from .load_backend  import control_flow_ops
# from .load_backend import set_image_dim_ordering
#
# 1)!pip install keras==2.2.0
# 2)!pip install tensorflow==1.14.0
#
# 1,2 solves set.graph attribute error
