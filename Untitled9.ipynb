# %% [markdown]
# <a href="https://colab.research.google.com/github/kushi3/Python/blob/master/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone  https://github.com/AntonMu/TrainYourOwnYOLO.git
# Out:
# Cloning into 'TrainYourOwnYOLO'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 2266 (delta 1), reused 2 (delta 0), pack-reused 2259
# Receiving objects: 100% (2266/2266), 142.02 MiB | 34.70 MiB/s, done.
# Resolving deltas: 100% (741/741), done.

# %%
# %cd TrainYourOwnYOLO/Data/Source_Images/
# Out:
# /content/TrainYourOwnYOLO/Data/Source_Images

# %%
# !rm -rf Training_Images

# %%
# !rm -rf Test_Images

# %%
# !rm -rf Test_Image_Detection_Results

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 1_Image_Annotation/
# Out:
# /content/TrainYourOwnYOLO/1_Image_Annotation

# %%
# !python Convert_to_YOLO_format.py

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 2_Training/
# Out:
# /content/TrainYourOwnYOLO/2_Training

# %%
# !python Download_and_Convert_YOLO_weights.py
# Out:
#  99% (2479879 of 2480070) |############## | Elapsed Time: 0:01:34 ETA:   0:00:00Using TensorFlow backend.
# 2020-05-02 16:18:26.736605: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# 2020-05-02 16:18:28.303004: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-02 16:18:28.369692: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-02 16:18:28.370335: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# ...

# %%
# !python Train_YOLO.py
# Out:
# Using TensorFlow backend.
# 2020-05-02 16:21:58.587005: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-02 16:22:00.075266: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-02 16:22:00.088305: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-02 16:22:00.088913: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-05-02 16:22:00.088952: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 3_Inference/
# Out:
# /content/TrainYourOwnYOLO/3_Inference

# %%
# !python Detector.py
# Out:
# Using TensorFlow backend.
# 2020-05-02 16:29:48.894665: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
#   File "Detector.py", line 179, in <module>
#     "model_image_size": (416, 416),
#   File "/content/TrainYourOwnYOLO/2_Training/src/keras_yolo3/yolo.py", line 45, in __init__
#     self.sess = K.get_session()
#   File "/usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py", line 380, in get_session
#     '`get_session` is not available '
# RuntimeError: `get_session` is not available when using TensorFlow 2.0.

# %%
# !pip install keras==2.2.0
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/f8/33/275506afe1d96b221f66f95adba94d1b73f6b6087cfb6132a5655b6fe338/Keras_Preprocessing-1.0.1-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/e2/60/c557075e586e968d7a9c314aa38c236b37cb3ee6b37e8d57152b1a5e0b47/Keras_Applications-1.0.2-py2.py3-none-any.whl
# ERROR: tensorflow 1.14.0 has requirement keras-applications>=1.0.6, but you'll have keras-applications 1.0.2 which is incompatible.
# ERROR: tensorflow 1.14.0 has requirement keras-preprocessing>=1.0.5, but you'll have keras-preprocessing 1.0.1 which is incompatible.
# ...
#   Found existing installation: Keras-Preprocessing 1.1.0
#     Uninstalling Keras-Preprocessing-1.1.0:
#       Successfully uninstalled Keras-Preprocessing-1.1.0
#   Found existing installation: Keras-Applications 1.0.8
#     Uninstalling Keras-Applications-1.0.8:
#       Successfully uninstalled Keras-Applications-1.0.8
# ...

# %%
# !pip install tensorflow==1.14.0
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl
# ...
# ERROR: keras 2.2.0 has requirement keras-applications==1.0.2, but you'll have keras-applications 1.0.8 which is incompatible.
# ERROR: keras 2.2.0 has requirement keras-preprocessing==1.0.1, but you'll have keras-preprocessing 1.1.0 which is incompatible.
# ...
#   Found existing installation: Keras-Preprocessing 1.0.1
#     Uninstalling Keras-Preprocessing-1.0.1:
#       Successfully uninstalled Keras-Preprocessing-1.0.1
#   Found existing installation: Keras-Applications 1.0.2
#     Uninstalling Keras-Applications-1.0.2:
#       Successfully uninstalled Keras-Applications-1.0.2
# ...

# %%
# !python Detector.py
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !pip install Keras-Applications==1.0.4
# Out:
# ...
#      |████████████████████████████████| 51kB 2.7MB/s
# ...
#   Using cached https://files.pythonhosted.org/packages/f8/33/275506afe1d96b221f66f95adba94d1b73f6b6087cfb6132a5655b6fe338/Keras_Preprocessing-1.0.1-py2.py3-none-any.whl
# ...
# ERROR: tensorflow 1.14.0 has requirement keras-applications>=1.0.6, but you'll have keras-applications 1.0.4 which is incompatible.
# ERROR: tensorflow 1.14.0 has requirement keras-preprocessing>=1.0.5, but you'll have keras-preprocessing 1.0.1 which is incompatible.
# ERROR: keras 2.2.0 has requirement keras-applications==1.0.2, but you'll have keras-applications 1.0.4 which is incompatible.
# ...
#   Found existing installation: Keras-Applications 1.0.8
#     Uninstalling Keras-Applications-1.0.8:
#       Successfully uninstalled Keras-Applications-1.0.8
#   Found existing installation: Keras-Preprocessing 1.1.0
#     Uninstalling Keras-Preprocessing-1.1.0:
#       Successfully uninstalled Keras-Preprocessing-1.1.0
# ...

# %% [markdown]
# AttributeError: module 'keras_applications' has no attribute 'set_keras_submodules'
#
# https://github.com/tensorflow/tensorflow/issues/25062
