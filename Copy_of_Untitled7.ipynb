# %% [markdown]
# <a href="https://colab.research.google.com/github/kushi3/Python/blob/master/Copy_of_Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AntonMu/TrainYourOwnYOLO.git
# Out:
# Cloning into 'TrainYourOwnYOLO'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 2266 (delta 1), reused 2 (delta 0), pack-reused 2259
# Receiving objects: 100% (2266/2266), 142.02 MiB | 37.20 MiB/s, done.
# Resolving deltas: 100% (741/741), done.

# %%
# %cd TrainYourOwnYOLO/Data/Source_Images/
# Out:
# /content/TrainYourOwnYOLO/Data/Source_Images

# %%
# !rm -rf Training_Images

# %%
# !rm -rf Test_Images

# %%
# !rm -rf Test_Image_Detection_Results/

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# !pip install keras==2.2.0
# !pip install tensorflow==1.14.0
# Out:
# ...
#      |████████████████████████████████| 307kB 3.4MB/s
# ...
#      |████████████████████████████████| 51kB 7.8MB/s
# ...
# ERROR: tensorflow 2.2.0rc3 has requirement keras-preprocessing>=1.1.0, but you'll have keras-preprocessing 1.0.1 which is incompatible.
# ...
#   Found existing installation: Keras-Applications 1.0.8
#     Uninstalling Keras-Applications-1.0.8:
#       Successfully uninstalled Keras-Applications-1.0.8
#   Found existing installation: Keras-Preprocessing 1.1.0
#     Uninstalling Keras-Preprocessing-1.1.0:
#       Successfully uninstalled Keras-Preprocessing-1.1.0
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# ...
#      |████████████████████████████████| 109.2MB 38kB/s
# ...
#      |████████████████████████████████| 3.2MB 50.4MB/s
# ...
#      |████████████████████████████████| 51kB 8.8MB/s
# ...
#      |████████████████████████████████| 51kB 7.7MB/s
# ...
#      |████████████████████████████████| 491kB 57.8MB/s
# ...

# %%
# %cd TrainYourOwnYOLO
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 1_Image_Annotation/
# Out:
# /content/TrainYourOwnYOLO/1_Image_Annotation

# %%
# !python Convert_to_YOLO_format.py

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 2_Training/
# Out:
# /content/TrainYourOwnYOLO/2_Training

# %%
# !python Download_and_Convert_YOLO_weights.py
# Out:
# 100% (2480070 of 2480070) |###############| Elapsed Time: 0:09:20 ETA:  00:00:00Using TensorFlow backend.
# 2020-05-01 15:47:32.368777: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# 2020-05-01 15:47:33.884402: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-01 15:47:33.944056: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-01 15:47:33.944745: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# ...

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.14.0

# %%
# !python Train_YOLO.py
# Out:
# Using TensorFlow backend.
# 2020-05-01 16:06:45.001789: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-01 16:06:46.435874: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-01 16:06:46.453702: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-01 16:06:46.454273: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-05-01 16:06:46.454311: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !pip install keras==2.3.1
# !pip install tensorflow==1.15.0
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/ad/fd/6bfe87920d7f4fd475acd28500a42482b6b84479832bdc0fe9e589a60ceb/Keras-2.3.1-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl
# ...
#   Found existing installation: Keras-Applications 1.0.4
#     Uninstalling Keras-Applications-1.0.4:
#       Successfully uninstalled Keras-Applications-1.0.4
#   Found existing installation: Keras-Preprocessing 1.0.2
#     Uninstalling Keras-Preprocessing-1.0.2:
#       Successfully uninstalled Keras-Preprocessing-1.0.2
#   Found existing installation: Keras 2.2.1
#     Uninstalling Keras-2.2.1:
#       Successfully uninstalled Keras-2.2.1
# ...
#      |████████████████████████████████| 412.3MB 43kB/s
# ...

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 3_Inference/
# Out:
# /content/TrainYourOwnYOLO/3_Inference

# %%
# !python Detector.py
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !pip install tensorflow==1.14.0
# !pip install keras==2.2.0
# Out:
# ...
#      |████████████████████████████████| 109.2MB 37kB/s
# ...
#      |████████████████████████████████| 491kB 43.1MB/s
# ...
#      |████████████████████████████████| 3.2MB 52.2MB/s
# ...
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: tensorboard 2.2.1
#     Uninstalling tensorboard-2.2.1:
#       Successfully uninstalled tensorboard-2.2.1
#   Found existing installation: tensorflow 2.2.0rc3
#     Uninstalling tensorflow-2.2.0rc3:
#       Successfully uninstalled tensorflow-2.2.0rc3
# ...
#      |████████████████████████████████| 307kB 8.5MB/s
# ...
#      |████████████████████████████████| 51kB 8.6MB/s
# ...
# ERROR: tensorflow 1.14.0 has requirement keras-applications>=1.0.6, but you'll have keras-applications 1.0.2 which is incompatible.
# ...

# %%
# !pip install tensorflow==1.12
# Out:
# ...
#      |████████████████████████████████| 83.1MB 52kB/s
# ...
#      |████████████████████████████████| 3.1MB 52.1MB/s
# ...
#   Found existing installation: tensorboard 2.2.1
#     Uninstalling tensorboard-2.2.1:
#       Successfully uninstalled tensorboard-2.2.1
#   Found existing installation: tensorflow 2.2.0rc3
#     Uninstalling tensorflow-2.2.0rc3:
#       Successfully uninstalled tensorflow-2.2.0rc3
# ...

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd Data/Source_Images/
# Out:
# /content/TrainYourOwnYOLO/Data/Source_Images

# %%
# !rm -rf Training_Images/

# %%
# !rm -rf Test_Images

# %%
# !rm -rf Test_Image_Detection_Results

# %%
# %cd Training_Images/
# Out:
# /content/TrainYourOwnYOLO/Data/Source_Images/Training_Images

# %%
# !rm -rf vott-export-csv

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 1_Image_Annotation/
# Out:
# /content/TrainYourOwnYOLO/1_Image_Annotation

# %%
# !python Convert_to_YOLO_format.py

# %%
# %cd ..
# Out:
# /content/TrainYourOwnYOLO

# %%
# %cd 2_Training/
# Out:
# /content/TrainYourOwnYOLO/2_Training

# %%
# !python Download_and_Convert_YOLO_weights.py
# Out:
#  99% (2479715 of 2480070) |############## | Elapsed Time: 0:07:47 ETA:   0:00:00Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %%
# !python Train_YOLO.py
# Out:
# 1/1 [==============================] - 87s 87s/step - loss: 315.8076 - val_loss: 185.6694
# Epoch 48/51
# 1/1 [==============================] - 87s 87s/step - loss: 315.8076 - val_loss: 185.6694
# Epoch 48/51
# 1/1 [==============================] - 89s 89s/step - loss: 315.2775 - val_loss: 171.7051
# Epoch 49/51
# 1/1 [==============================] - 89s 89s/step - loss: 315.2775 - val_loss: 171.7051
# Epoch 49/51
# 1/1 [==============================] - 88s 88s/step - loss: 297.4109 - val_loss: 170.0347
# Epoch 50/51
# 1/1 [==============================] - 88s 88s/step - loss: 297.4109 - val_loss: 170.0347
# Epoch 50/51
# ...
# 1/1 [==============================] - 87s 87s/step - loss: 330.1060 - val_loss: 156.0443
# Epoch 51/51
# Epoch 51/51
# ...
# 1/1 [==============================] - 87s 87s/step - loss: 280.6579 - val_loss: 173.9858
# Unfreeze all layers.
# Train on 18 samples, val on 1 samples, with batch size 4.
# Unfreeze all layers.
# ...

# %%
# %cd ..

# %%
# %cd 3_Inference

# %%
# !python Train_YOLO.py

# %% [markdown]
# https://stackoverflow.com/questions/58963553/attributeerror-module-tensorflow-python-keras-backend-has-no-attribute-get-g
#
#
# https://github.com/keras-team/keras/issues/12379
#
# https://github.com/OlafenwaMoses/ImageAI/issues/367
#
# https://blog.insightdatascience.com/how-to-train-your-own-yolov3-detector-from-scratch-224d10e55de2
#
# https://github.com/AntonMu/TrainYourOwnYOLO/tree/master/1_Image_Annotation
#
# https://blog.csdn.net/CAU_Ayao/article/details/89312354
#
# https://github.com/AntonMu/TrainYourOwnYOLO/issues/48
#
# https://github.com/AntonMu/TrainYourOwnYOLO

# %% [markdown]
# solving attribute errors,module not found errors,import errors
#
# add
#
# import tensorflow.python.ops import control_flow_ops in Tensorflow backend.py
#
# in __init.py__ we add
# from .load_backend  import control_flow_ops
# from .load_backend import set_image_dim_ordering
#
# 1)!pip install keras==2.2.0
# 2)!pip install tensorflow==1.14.0
#
# 1,2 solves set.graph attribute error
